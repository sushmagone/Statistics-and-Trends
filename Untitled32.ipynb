# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data from csv
data = pd.read_csv('Restaurant_revenue .csv')
data
# Out:
#      Number_of_Customers  Menu_Price  Marketing_Spend Cuisine_Type  \
# 0                     61   43.117635        12.663793     Japanese
# 1                     24   40.020077         4.577892      Italian
# 2                     81   41.981485         4.652911     Japanese
# 3                     70   43.005307         4.416053      Italian
# 4                     30   17.456199         3.475052      Italian
# ..                   ...         ...              ...          ...
# 995                   73   41.307842        12.122931     Japanese
# 996                   31   20.615496         5.822885      Mexican
# 997                   69   17.110656         4.141898     Japanese
# 998                   73   37.664722         3.046556     Japanese
# 999                   81   34.722067        17.989104      Italian
#
#      Average_Customer_Spending  Promotions  Reviews  Monthly_Revenue
# 0                    36.236133           0       45       350.912040
# ...

# %%
# drop duplicates
data.drop_duplicates(inplace=True)

# %%
# 1. Inspect for missing values
print("Missing Values before Cleaning:")
print(data.isnull().sum())
# Out:
# Missing Values before Cleaning:
# Number_of_Customers          0
# Menu_Price                   0
# Marketing_Spend              0
# Cuisine_Type                 0
# Average_Customer_Spending    0
# Promotions                   0
# Reviews                      0
# Monthly_Revenue              0
# dtype: int64

# %%
print("\nData after Cleaning:")
print("Missing Values after Cleaning:")
print(data.isnull().sum())
print("Data Types after Cleaning:")
print(data.dtypes)
print("Number of Duplicates after Cleaning:", data.duplicated().sum())
# Out:
# Data after Cleaning:
# Missing Values after Cleaning:
# Number_of_Customers          0
# Menu_Price                   0
# Marketing_Spend              0
# Cuisine_Type                 0
# Average_Customer_Spending    0
# Promotions                   0
# Reviews                      0
# Monthly_Revenue              0
# dtype: int64
# Data Types after Cleaning:
# Number_of_Customers            int64
# Menu_Price                   float64
# Marketing_Spend              float64
# Cuisine_Type                  object
# Average_Customer_Spending    float64
# Promotions                     int64
# Reviews                        int64
# Monthly_Revenue              float64
# dtype: object
# Number of Duplicates after Cleaning: 0

# %%
def describe_statistics(data):
    """Displays the descriptive statistics for the dataset."""
    return data.describe()
describe_statistics(data)
# Out:
#        Number_of_Customers   Menu_Price  Marketing_Spend  \
# count          1000.000000  1000.000000      1000.000000
# mean             53.271000    30.219120         9.958726
# std              26.364914    11.278760         5.845586
# min              10.000000    10.009501         0.003768
# 25%              30.000000    20.396828         4.690724
# 50%              54.000000    30.860614        10.092047
# 75%              74.000000    39.843868        14.992436
# max              99.000000    49.974140        19.994276
#
#        Average_Customer_Spending   Promotions      Reviews  Monthly_Revenue
# count                1000.000000  1000.000000  1000.000000      1000.000000
# mean                   29.477085     0.497000    49.837000       268.724172
# std                    11.471686     0.500241    29.226334       103.982950
# min                    10.037177     0.000000     0.000000       -28.977809
# ...

# %%
def correlation_statistics(data):
    """Displays the correlation matrix for numerical features."""
    return data.corr(numeric_only=True)
correlation_statistics(data)
# Out:
#                            Number_of_Customers  Menu_Price  Marketing_Spend  \
# Number_of_Customers                   1.000000    0.033470        -0.007024
# Menu_Price                            0.033470    1.000000         0.016319
# Marketing_Spend                      -0.007024    0.016319         1.000000
# Average_Customer_Spending            -0.013898    0.020808        -0.058586
# Promotions                            0.058693    0.022068        -0.041838
# Reviews                              -0.010140    0.003792        -0.031470
# Monthly_Revenue                       0.745239    0.259579         0.269929
#
#                            Average_Customer_Spending  Promotions   Reviews  \
# Number_of_Customers                        -0.013898    0.058693 -0.010140
# Menu_Price                                  0.020808    0.022068  0.003792
# Marketing_Spend                            -0.058586   -0.041838 -0.031470
# ...

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
statistics = pd.DataFrame({
    'Mean': numeric_data.mean(),
    'Median': numeric_data.median(),
    'Standard Deviation': numeric_data.std(),
    'Skewness': numeric_data.skew()
})
print(statistics)
# Out:
#                                  Mean      Median  Standard Deviation  \
# Number_of_Customers         53.271000   54.000000           26.364914
# Menu_Price                  30.219120   30.860614           11.278760
# Marketing_Spend              9.958726   10.092047            5.845586
# Average_Customer_Spending   29.477085   29.251365           11.471686
# Promotions                   0.497000    0.000000            0.500241
# Reviews                     49.837000   50.000000           29.226334
# Monthly_Revenue            268.724172  270.213964          103.982950
#
#                            Skewness
# Number_of_Customers        0.044938
# Menu_Price                -0.055330
# Marketing_Spend           -0.026283
# Average_Customer_Spending  0.025268
# Promotions                 0.012018
# Reviews                    0.018223
# Monthly_Revenue           -0.055728

# %%
# 1. Bar Chart for Cuisine_Type Distribution
def plot_cuisine_distribution(data):
    """Creates a bar chart of the distribution of restaurants by Cuisine_Type."""
    plt.figure(figsize=(8, 5))
    data['Cuisine_Type'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title('Distribution of Restaurants by Cuisine Type')
    plt.xlabel('Cuisine Type')
    plt.ylabel('Number of Restaurants')
    plt.xticks(rotation=45)
    plt.show()

plot_cuisine_distribution(data)

# %%
# 2. Scatter Plot for Marketing Spend vs Monthly Revenue
def plot_marketing_vs_revenue(data):
    """Creates a scatter plot of Marketing Spend vs Monthly Revenue."""
    plt.figure(figsize=(8, 5))
    sns.scatterplot(data=data, x='Marketing_Spend', y='Monthly_Revenue', hue='Cuisine_Type', palette='viridis')
    plt.title('Marketing Spend vs Monthly Revenue')
    plt.xlabel('Marketing Spend')
    plt.ylabel('Monthly Revenue')
    plt.legend(title='Cuisine Type')
    plt.show()

plot_marketing_vs_revenue(data)

# %%
# 3. Heatmap of Correlation Matrix for Numerical Columns
def plot_correlation_heatmap(data):
    """Creates a heatmap of the correlation matrix for numerical features."""
    plt.figure(figsize=(10, 8))
    correlation_matrix = data.corr(numeric_only=True)
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
    plt.title('Correlation Matrix Heatmap')
    plt.show()

plot_correlation_heatmap(data)
